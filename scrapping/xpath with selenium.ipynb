# %%
# Se utiliza selenium para dar click en el boton debido a que es una pagina dinamica
import time
from lxml import html
import pandas as pd
from selenium import webdriver

#Se levanda un webdriver
options = webdriver.ChromeOptions()
options.add_argument("start-maximized"); # open Browser in maximized mode
options.add_argument('--headless')
options.add_argument("--disable-infobars"); # disabling infobars
options.add_argument("--disable-extensions"); # disabling extensions
options.add_argument("--disable-gpu"); # applicable to windows os only
options.add_argument("--disable-dev-shm-usage"); # overcome limited resource problems
options.add_argument("--no-sandbox"); # Bypass OS security model
options.add_argument('--remote-debugging-port=9222')
chrome_driver = "/tmp/chromedriver/chromedriver"
driver = webdriver.Chrome(executable_path=chrome_driver, chrome_options=options)

#Se ejecutan los pasos correspondientes para llegar a la tabla
root_link = "https://en.wikipedia.org"
first_link = "/wiki/Kevin_Bacon"
driver.get(root_link + first_link)
# Out:
# <ipython-input-38-b490380db3db>:18: DeprecationWarning: use options instead of chrome_options
#   driver = webdriver.Chrome(executable_path=chrome_driver, chrome_options=options)

# %%
page = html.fromstring(driver.page_source)

elements = page.xpath("//a[@href]")
links = []
for element in elements:
    href = element.get("href")
    if(href.find("/wiki/") != -1):
        links.append(element.get("href"))

LAST_MODIFIED = page.xpath('//*[@id="footer-info-lastmod"]/text()')
TITLE = page.xpath('//*[@id="firstHeading"]/text()')
print( root_link + first_link, TITLE, LAST_MODIFIED)

for link in links:
    driver.get(root_link + link)
    page = html.fromstring(driver.page_source)
    
    LAST_MODIFIED = page.xpath('//*[@id="footer-info-lastmod"]/text()')
    TITLE = page.xpath('//*[@id="firstHeading"]/text()')
    
    print( root_link + link, TITLE, LAST_MODIFIED)
# Out:
# https://en.wikipedia.org/wiki/Kevin_Bacon ['Kevin Bacon'] [' This page was last edited on 1 January 2021, at 17:28', '.']
# https://en.wikipedia.org/wiki/Wikipedia:Protection_policy#semi ['Wikipedia:Protection policy'] [' This page was last edited on 7 January 2021, at 12:29', '.']
# https://en.wikipedia.org/wiki/Kevin_Bacon_(disambiguation) ['Kevin Bacon (disambiguation)'] [' This page was last edited on 11 April 2020, at 17:44', '.']
# https://en.wikipedia.org/wiki/File:Kevin_Bacon_SDCC_2014.jpg ['File:Kevin Bacon SDCC 2014.jpg'] []
# https://en.wikipedia.org/wiki/Philadelphia,_Pennsylvania ['Philadelphia'] [' This page was last edited on 27 December 2020, at 01:56', '.']
# https://en.wikipedia.org/wiki/Kyra_Sedgwick ['Kyra Sedgwick'] [' This page was last edited on 7 December 2020, at 10:10', '.']
# https://en.wikipedia.org/wiki/Sosie_Bacon ['Sosie Bacon'] [' This page was last edited on 3 November 2020, at 00:55', '.']
# ...

# %%
tests = page.xpath("//a[@href]")

# %%
for element in tests:
    href = element.get("href")
    if(href.find("/wiki/") != -1):
        print(element.get("href"))
    

#tests[0].get("href")
# Out:
# /wiki/Wikipedia:Protection_policy#semi
# /wiki/Kevin_Bacon_(disambiguation)
# /wiki/File:Kevin_Bacon_SDCC_2014.jpg
# /wiki/Philadelphia,_Pennsylvania
# /wiki/Kyra_Sedgwick
# /wiki/Sosie_Bacon
# /wiki/Edmund_Bacon_(architect)
# /wiki/Michael_Bacon_(musician)
# /wiki/Holly_Near
# /wiki/Footloose_(1984_film)
# /wiki/JFK_(film)
# /wiki/A_Few_Good_Men
# /wiki/Apollo_13_(film)
# /wiki/Mystic_River_(film)
# /wiki/Balto_(film)
# /wiki/Sleepers
# /wiki/The_Woodsman_(2004_film)
# /wiki/Animal_House
# /wiki/Diner_(1982_film)
# /wiki/Tremors_(1990_film)
# /wiki/Crazy,_Stupid,_Love
# /wiki/Friday_the_13th_(1980_film)
# /wiki/Flatliners
# /wiki/The_River_Wild
# /wiki/Wild_Things_(film)
# /wiki/Stir_of_Echoes
# /wiki/Hollow_Man
# /wiki/Frost/Nixon_(film)
# /wiki/X-Men:_First_Class
# /wiki/Black_Mass_(film)
# /wiki/Patriots_Day_(film)
# /wiki/Fox_Broadcasting_Company
# /wiki/The_Following
# /wiki/HBO
# /wiki/Taking_Chance
# /wiki/Golden_Globe_Award
# /wiki/Screen_Actors_Guild_Award
# ...
